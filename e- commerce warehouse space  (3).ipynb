# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dspace=pd.read_csv("C:\\Users\\HP 745 G6\\Documents\\ecommerce_warehouse_dataset.csv")

# %%
dspace
# Out:
#     Product_ID  Product_Name         Category Warehouse_Location  \
# 0        P0001     Product_1  Health & Beauty   Aisle 3, Shelf 2
# 1        P0002     Product_2      Electronics  Aisle 14, Shelf 6
# 2        P0003     Product_3      Electronics  Aisle 11, Shelf 6
# 3        P0004     Product_4         Clothing  Aisle 18, Shelf 8
# 4        P0005     Product_5            Books  Aisle 14, Shelf 5
# ..         ...           ...              ...                ...
# 995      P0996   Product_996      Electronics  Aisle 10, Shelf 9
# 996      P0997   Product_997  Health & Beauty  Aisle 13, Shelf 4
# 997      P0998   Product_998      Electronics  Aisle 17, Shelf 1
# 998      P0999   Product_999         Clothing   Aisle 3, Shelf 8
# 999      P1000  Product_1000             Toys  Aisle 18, Shelf 9
#
#           Section  Quantity_Stored  Unit_Size  Total_Warehouse_Space  \
# 0     Perishables              225       0.38                   6833
# ...

# %%
dspace.head(5)
# Out:
#   Product_ID Product_Name         Category Warehouse_Location       Section  \
# 0      P0001    Product_1  Health & Beauty   Aisle 3, Shelf 2   Perishables
# 1      P0002    Product_2      Electronics  Aisle 14, Shelf 6  Refrigerated
# 2      P0003    Product_3      Electronics  Aisle 11, Shelf 6  Refrigerated
# 3      P0004    Product_4         Clothing  Aisle 18, Shelf 8  Refrigerated
# 4      P0005    Product_5            Books  Aisle 14, Shelf 5  Refrigerated
#
#    Quantity_Stored  Unit_Size  Total_Warehouse_Space  Cost_Per_Unit  \
# 0              225       0.38                   6833           0.79
# 1              370       0.71                  11667           9.12
# 2              189       0.34                  10888          12.95
# 3               58       0.68                   7039          13.52
# 4               39       0.60                  16988           8.00
#
#    Selling_Price_Per_Unit Date_Recorded  Total_Space_Used  Utilization_Rate  \
# ...

# %%
## checking nans
dspace.isnull().sum()
# Out:
# Product_ID                0
# Product_Name              0
# Category                  0
# Warehouse_Location        0
# Section                   0
# Quantity_Stored           0
# Unit_Size                 0
# Total_Warehouse_Space     0
# Cost_Per_Unit             0
# Selling_Price_Per_Unit    0
# Date_Recorded             0
# Total_Space_Used          0
# Utilization_Rate          0
# Total_Cost                0
# Total_Revenue             0
# Profit                    0
# dtype: int64

# %%
sns.boxplot(dspace)
plt.xticks(rotation=70)
plt.show()

# %%
sns.displot(dspace)

# %%
dspace.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Product_ID              1000 non-null   object
#  1   Product_Name            1000 non-null   object
#  2   Category                1000 non-null   object
#  3   Warehouse_Location      1000 non-null   object
#  4   Section                 1000 non-null   object
#  5   Quantity_Stored         1000 non-null   int64
#  6   Unit_Size               1000 non-null   float64
#  7   Total_Warehouse_Space   1000 non-null   int64
#  8   Cost_Per_Unit           1000 non-null   float64
#  9   Selling_Price_Per_Unit  1000 non-null   float64
#  10  Date_Recorded           1000 non-null   object
#  11  Total_Space_Used        1000 non-null   float64
#  12  Utilization_Rate        1000 non-null   float64
#  13  Total_Cost              1000 non-null   float64
# ...

# %%
dspace.columns
# Out:
# Index(['Product_ID', 'Product_Name', 'Category', 'Warehouse_Location',
#        'Section', 'Quantity_Stored', 'Unit_Size', 'Total_Warehouse_Space',
#        'Cost_Per_Unit', 'Selling_Price_Per_Unit', 'Date_Recorded',
#        'Total_Space_Used', 'Utilization_Rate', 'Total_Cost', 'Total_Revenue',
#        'Profit'],
#       dtype='object')

# %%
dspace.describe()
# Out:
#        Quantity_Stored   Unit_Size  Total_Warehouse_Space  Cost_Per_Unit  \
# count      1000.000000  1000.00000            1000.000000    1000.000000
# mean        251.115000     0.75858           12364.529000       7.549330
# std         142.003418     0.42038            4342.019299       4.121524
# min          10.000000     0.01000            5001.000000       0.500000
# 25%         131.000000     0.41000            8601.250000       4.000000
# 50%         244.500000     0.74000           12199.000000       7.440000
# 75%         373.250000     1.14000           15987.750000      11.040000
# max         499.000000     1.50000           19990.000000      15.000000
#
#        Selling_Price_Per_Unit  Total_Space_Used  Utilization_Rate  \
# count             1000.000000       1000.000000       1000.000000
# mean                25.548390        187.710370          1.747670
# std                 14.188591        156.869226          1.728061
# ...

# %%
dcols=[  'Total_Space_Used', 'Utilization_Rate', 'Total_Cost', 'Total_Revenue', 'Profit']

# %%
dcols
# Out:
# ['Total_Space_Used',
#  'Utilization_Rate',
#  'Total_Cost',
#  'Total_Revenue',
#  'Profit']

# %%
sns.boxplot(dspace["Quantity_Stored"])
# Out:
# <Axes: ylabel='Quantity_Stored'>

# %%
for i in dcols:
    skew=dspace[i].skew().round()
    print(skew)
# Out:
# 1.0
# 2.0
# 1.0
# 1.0
# 1.0

# %%
for i in dcols:
    q1=dspace[i].quantile(0.25)
    q3=dspace[i].quantile(0.75)
    iqr=q3-q1
    upperlimit=q3+1.5*iqr
    lowerlimit=q1-1.5*iqr
    dspace[i]=dspace[i].map(lambda x: upperlimit if x>upperlimit else lowerlimit if x<lowerlimit else x)

# %%
dspace
# Out:
#     Product_ID  Product_Name         Category Warehouse_Location  \
# 0        P0001     Product_1  Health & Beauty   Aisle 3, Shelf 2
# 1        P0002     Product_2      Electronics  Aisle 14, Shelf 6
# 2        P0003     Product_3      Electronics  Aisle 11, Shelf 6
# 3        P0004     Product_4         Clothing  Aisle 18, Shelf 8
# 4        P0005     Product_5            Books  Aisle 14, Shelf 5
# ..         ...           ...              ...                ...
# 995      P0996   Product_996      Electronics  Aisle 10, Shelf 9
# 996      P0997   Product_997  Health & Beauty  Aisle 13, Shelf 4
# 997      P0998   Product_998      Electronics  Aisle 17, Shelf 1
# 998      P0999   Product_999         Clothing   Aisle 3, Shelf 8
# 999      P1000  Product_1000             Toys  Aisle 18, Shelf 9
#
#           Section  Quantity_Stored  Unit_Size  Total_Warehouse_Space  \
# 0     Perishables              225       0.38                   6833
# ...

# %%
sns.boxplot(dspace)
plt.xticks(rotation=90)
plt.show()

# %%
dspace
# Out:
#     Product_ID  Product_Name         Category Warehouse_Location  \
# 0        P0001     Product_1  Health & Beauty   Aisle 3, Shelf 2
# 1        P0002     Product_2      Electronics  Aisle 14, Shelf 6
# 2        P0003     Product_3      Electronics  Aisle 11, Shelf 6
# 3        P0004     Product_4         Clothing  Aisle 18, Shelf 8
# 4        P0005     Product_5            Books  Aisle 14, Shelf 5
# ..         ...           ...              ...                ...
# 995      P0996   Product_996      Electronics  Aisle 10, Shelf 9
# 996      P0997   Product_997  Health & Beauty  Aisle 13, Shelf 4
# 997      P0998   Product_998      Electronics  Aisle 17, Shelf 1
# 998      P0999   Product_999         Clothing   Aisle 3, Shelf 8
# 999      P1000  Product_1000             Toys  Aisle 18, Shelf 9
#
#           Section  Quantity_Stored  Unit_Size  Total_Warehouse_Space  \
# 0     Perishables              225       0.38                   6833
# ...

# %%
plt.bar(dspace["Date_Recorded"],dspace["Profit"],color="orange")
plt.xticks(rotation=90)
plt.xlabel("Date of records")
plt.ylabel("Profit")
plt.show()

# %%
plt.hist(dspace["Utilization_Rate"],bins=5,color="b",width=0.7)
plt.grid()
plt.show()

# %%
dspace.to_excel("output.xlsx",index=False)
